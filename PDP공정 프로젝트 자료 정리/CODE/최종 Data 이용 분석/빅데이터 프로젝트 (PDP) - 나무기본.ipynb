# %% [markdown]
# # 모듈 가져오기 (IMPORT 단계)

# %%
# 데이터 구성: Series, DataFrame
import pandas as pd
import numpy as np


#탐색적 분석을 위한 패키지
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale,minmax_scale,robust_scale
from scipy.stats import shapiro

#ARIMA
from statsmodels.tsa.arima_model import ARIMA



#matplotlib 이용한 background 그래프 실행 및 결과 확인 
# %matplotlib inline


#export_graphviz: 나무구조 생성 및 저장
from sklearn.tree import export_graphviz
#graphviz: 나무 구조 시각화(.dot 확장자 파일 불러오기 등)
import graphviz


# 데이터 분할: train,test
from sklearn.model_selection import train_test_split

#데이터 scaling => 거리기반 알고리즘은 필수!!!
from sklearn.preprocessing import StandardScaler
# 데이터 분할: train,test
from sklearn.model_selection import train_test_split
# 분류 DT
from sklearn.tree import DecisionTreeClassifier
#분류  RF
from sklearn.ensemble import RandomForestClassifier
# 분류 GB
from sklearn.ensemble import GradientBoostingClassifier
# 분류 SVM
from sklearn.svm import SVC
# 분류 KNN
from sklearn.neighbors import KNeighborsClassifier
# 분류 NN
from sklearn.neural_network import MLPClassifier

# 최적모델, 파라미터 탐색
from sklearn.model_selection import GridSearchCV
# 모델 성능 평가 
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# 한글 폰트 적용
font_path = '/usr/share/fonts/opentype/noto/NotoSerifCJK-ExtraLight.ttc'
font_name = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family = font_name)

# %%
#결과 창 확대
# pd.set_option('display.max_rows', 100000000000) # 최대 줄 수 설정
# pd.set_option('display.max_columns', 100000000000) # 최대 열 수 설정 
# pd.set_option('display.width', 1000) # 표시할 가로의 길이

# %% [markdown]
# ## 데이터 받아오기

# %%
# 데이터 구성하기(MFG_MACHINE)
MFG_MACHINE = pd.read_csv("/home/pirl/Documents/FMACHINE.csv", engine="python", encoding = "euc-kr")
MFG_MACHINE.head()
# Out:
#   JUDGE   LOT_ID PANEL_ID MC_1BLACK_1PRINT MC_1BLACK_2RTD MC_2AG_1PRINT MC_2AG_2RTD MC_2AG_3EXPOSURE MC_3BUS_1DEVELOP MC_3BUS_2FIRE MC_4DIELEC_1FIRE MC_5MGO MC_6PHOS_1R_1DISPENSER MC_6PHOS_1R_2DRY MC_6PHOS_2G_1DISPENSER MC_6PHOS_2G_2DRY MC_6PHOS_3B_1DISPENSER MC_6PHOS_4FIRE MC_7PASTE MC_8AGING
# 0    양품  LOT-101   PNL-01              2호기            2호기           1호기         1호기              2호기              1호기           1호기              3호기     1호기                    1호기              2호기                    2호기              2호기                    1호기            3호기       1호기       2호기
# 1    양품  LOT-101   PNL-02              2호기            2호기           1호기         1호기              2호기              1호기           1호기              3호기     1호기                    1호기              2호기                    2호기              2호기                    1호기            3호기       1호기       2호기
# 2    양품  LOT-101   PNL-03              2호기            2호기           1호기         1호기              2호기              1호기           1호기              3호기     1호기                    1호기              2호기                    2호기              2호기                    1호기            3호기       1호기       2호기
# 3    양품  LOT-101   PNL-04              2호기            2호기           1호기         1호기              2호기              1호기           1호기              3호기     1호기                    1호기              2호기                    2호기              2호기                    1호기            3호기       1호기       2호기
# 4    양품  LOT-101   PNL-05              2호기            2호기           1호기         1호기              2호기              1호기           1호기              3호기     1호기                    1호기              2호기                    2호기              2호기                    1호기            3호기       1호기       2호기

# %%
# 데이터 구성하기(MFG_PROCESS)
MFG_PROCESS = pd.read_csv("/home/pirl/Documents/FPROCESS.csv", engine="python", encoding = "euc-kr")
MFG_PROCESS.head()
# Out:
#   JUDGE   LOT_ID PANEL_ID  BLACK_RTD_TEMP_GLASS_START  BLACK_RTD_TEMP_GLASS_END  BLACK_RTD_TEMP_WALL_START  BLACK_RTD_TEMP_WALL_MAX  BLACK_RTD_PRES_START  BLACK_RTD_PRES_END  BLACK_RTD_TEMP_GLASS_OUT  BLACK_RTD_TEMP_HOOD_START  BLACK_RTD_TEMP_HOOD_MAX  AG_RTD_TEMP_GLASS_START  AG_RTD_TEMP_GLASS_END  AG_RTD_TEMP_WALL_START  AG_RTD_TEMP_WALL_MAX  AG_RTD_PRES_START  AG_RTD_PRES_END  AG_RTD_TEMP_GLASS_OUT  AG_RTD_TEMP_HOOD_START  AG_RTD_TEMP_HOOD_MAX  AG_EXPOSURE_TEMP_MASK  BUS_DEVELOP_TEMP_OVEN1  BUS_DEVELOP_TEMP_OVEN2  BUS_DEVELOP_TEMP_OVEN3  BUS_DEVELOP_TEMP_TANK1  BUS_DEVELOP_TEMP_TANK2  BUS_DEVELOP_TEMP_TANK3  BUS_DEVELOP_PRES2  BUS_DEVELOP_PRES3  BUS_FIRE_TEMP_KEEP_CH01  BUS_FIRE_TEMP_KEEP_CH02  BUS_FIRE_TEMP_KEEP_CH03  BUS_FIRE_TEMP_ANEAL_CH01  BUS_FIRE_TEMP_ANEAL_CH02  BUS_FIRE_TEMP_ANEAL_CH03  DIELEC_FIRE_TEMP_KEEP_CH01  DIELEC_FIRE_TEMP_ANEAL_CH01  DIELEC_FIRE_TEMP_ANEAL_CH02  DIELEC_FIRE_TEMP_ANEAL_CH03  DIELEC_FIRE_EXHAUST_HEAT1  DIELEC_FIRE_EXHAUST_HEAT2  \
# 0    양품  LOT-101   PNL-01                        44.3                     102.3                       88.8                    114.8                 229.5               156.5                      58.9                       93.2                     96.0                     46.0                  138.0                    76.0                 102.0              321.0            434.0                   41.3                    92.0                  93.0                 23.660                  60.253                  61.796                  60.542                  23.496                  30.753                  34.305              2.030              2.052                      567                      583                      599                       572                       538                       519                         569                          570                          552                          534                       2017                       2200
# 1    양품  LOT-101   PNL-02                        44.6                     101.6                       88.7                    114.3                 216.9               155.9                      59.0                       93.9                     96.0                     46.0                  139.0                    77.9                 101.0              398.8            339.8                   45.6                    93.0                  93.0                 23.340                  61.528                  60.228                  63.139                  23.420                  30.800                  35.300              2.032              2.010                      569                      584                      600                       574                       541                       520                         573                          575                          558                          536                       2166                       2132
# 2    양품  LOT-101   PNL-03                        45.0                     114.3                       90.3                    115.0                 217.4               140.6                      58.7                       94.0                     95.7                     45.0                  138.0                    77.0                 102.0              358.0            347.0                   43.6                    93.0                  94.0                 23.600                  61.415                  63.796                  63.500                  23.139                  30.694                  33.015              2.033              2.061                      573                      584                      600                       575                       536                       519                         568                          570                          553                          535                       1984                       2178
# 3    양품  LOT-101   PNL-04                        44.0                     115.0                       88.6                    115.4                 242.5               152.4                      58.8                       94.0                     97.0                     46.1                  138.0                    77.8                 101.1              356.4            438.1                   45.1                    93.0                  93.0                 23.424                  61.446                  60.800                  64.220                  23.376                  30.691                  32.760              2.030              2.062                      561                      578                      594                       574                       539                       519                         569                          571                          551                          533                       2024                       2220
# 4    양품  LOT-101   PNL-05                        44.8                     109.6                       89.2                    114.5                 218.3               151.8                      57.3                       94.0                     95.5                     47.0                  138.0                    77.8                 101.4              327.8            398.4                   45.7                    92.0                  93.0                 23.666                  60.260                  61.601                  60.558                  23.358                  31.032                  33.867              2.032              2.060                      562                      578                      593                       572                       537                       518                         575                          572                          556                          533                       2163                       2128
#
#    DIELEC_FIRE_EXHAUST_HEAT3  DIELEC_FIRE_EXHAUST_HEAT4  DIELEC_FIRE_EXHAUST_HEAT5  DIELEC_FIRE_EXHAUST_HEAT6  DIELEC_FIRE_EXHAUST_HEAT7  PHOS_R_DRY_TEMP_GLASS_START  PHOS_R_DRY_TEMP_GLASS_END  PHOS_R_DRY_TEMP_WALL_START  PHOS_R_DRY_TEMP_WALL_MAX  PHOS_R_DRY_PRES_START  PHOS_R_DRY_PRES_END  PHOS_R_DRY_TEMP_GLASS_OUT  PHOS_R_DRY_TEMP_HOOD_START  PHOS_R_DRY_TEMP_HOOD_MAX  PHOS_G_DRY_TEMP_GLASS_START  PHOS_G_DRY_TEMP_GLASS_END  PHOS_G_DRY_TEMP_WALL_START  PHOS_G_DRY_TEMP_WALL_MAX  PHOS_G_DRY_PRES_START  PHOS_G_DRY_PRES_END  PHOS_G_DRY_TEMP_GLASS_OUT  PHOS_G_DRY_TEMP_HOOD_START  PHOS_G_DRY_TEMP_HOOD_MAX  PHOS_FIRE_TEMP_ANEAL_CH01  PHOS_FIRE_TEMP_ANEAL_CH02  PHOS_FIRE_TEMP_ANEAL_CH03  PHOS_FIRE_TEMP_ANEAL_CH04  PHOS_FIRE_EXHAUST_HEAT1  PHOS_FIRE_EXHAUST_HEAT2  PHOS_FIRE_EXHAUST_HEAT3  PHOS_FIRE_EXHAUST_HEAT4
# 0                       3168                     3639.0                       3283                       3148                       3215                         48.0                      136.0                       110.5                     167.8                   86.6                 70.9                       28.3                       126.0                    157.30                         47.2                      139.2                       111.0                     189.4                   55.9                 28.2                       32.4                        82.8                      84.0                        443                        419                        392                        372                   4115.0                   3973.0                     4432                   2506.0
# 1                       2290                     3331.0                       3971                       3030                       2960                         47.5                      136.0                       111.9                     167.2                   84.5                 71.8                       26.7                       131.0                    155.70                         46.5                      138.8                       106.0                     186.3                   59.8                 28.1                       32.9                        80.3                      81.8                        445                        423                        395                        374                   3642.0                   4097.0                     4499                   2573.0
# 2                       3194                     3484.0                       3324                       3182                       3123                         47.3                      136.0                       110.6                     168.5                   85.4                 73.6                       27.5                       131.0                    156.30                         46.9                      139.0                       108.4                     187.9                   48.5                 30.3                       29.4                        81.2                      82.2                        444                        421                        393                        372                   4063.0                   3972.0                     4460                   2502.0
# 3                       3230                     3574.0                       3306                       3338                       3168                         45.8                      135.8                       107.8                     166.5                   87.9                 74.5                       26.5                       118.0                    150.34                         46.2                      140.2                       112.6                     190.7                   55.1                 32.1                       34.7                        83.0                      84.0                        444                        420                        393                        372                   4131.0                   4011.0                     4466                   2522.0
# 4                       2330                     3269.0                       3900                       3037                       2949                         47.8                      136.0                       110.8                     168.1                   80.9                 74.7                       27.4                       102.0                    158.30                         47.0                      139.2                       103.2                     183.9                   55.8                 29.8                       32.8                        80.1                      82.0                        443                        420                        392                        372                   3632.0                   4073.0                     4482                   2584.0

# %%
# 데이터 구성하기(MFG_TAT)
MFG_TAT = pd.read_csv("/home/pirl/Documents/FTAT.csv", engine="python", encoding = "euc-kr")
MFG_TAT.head()
# Out:
#   JUDGE   LOT_ID PANEL_ID  TAT_1BLACK_1PRINT  TAT_1BLACK_2RTD  TAT_2AG_1PRINT  TAT_2AG_2RTD  TAT_2AG_3EXPOSURE  TAT_3BUS_1DEVELOP  TAT_3BUS_2FIRE  TAT_4DIELEC_FIRE  TAT_5MGO  TAT_6PHOS_1R_1DISPENSER  TAT_6PHOS_1R_2DRY  TAT_6PHOS_2G_1DISPENSER  TAT_6PHOS_2G_2DRY  TAT_6PHOS_3B_1DISPENSER  TAT_6PHOS_4FIRE  TAT_8AGING
# 0    양품  LOT-101   PNL-01                 86              220              83            74                160                416            6900              6447       530                       76                333                       88                396                       86             7140       10074
# 1    양품  LOT-101   PNL-02                 86              210              84            71                150                372            6693              6600       530                       80                438                       82                381                       84             6956       10075
# 2    양품  LOT-101   PNL-03                 78              220              78            69                148                368            6747              6597       530                       80                420                       92                396                       86             6840       10645
# 3    양품  LOT-101   PNL-04                 86              210              84            69                178                416            7137              6420       530                       78                429                       78                399                       90             6720       10076
# 4    양품  LOT-101   PNL-05                 86              210              84            69                132                380            7527              6453       540                       76                363                       82                393                       84             7110       10074

# %% [markdown]
# ## MACHINE

# %%
# drop: X변수와 변수 삭제
df_raw_x = MFG_MACHINE.drop(["JUDGE","PANEL_ID","LOT_ID"], axis=1, inplace=False)
df_raw_y = MFG_MACHINE["JUDGE"]
# get_dummies: 데이터의 문자형 변수에 대한 더미변수 생성
df_x_dummy = pd.get_dummies(df_raw_x)
df_raw_y = np.where(df_raw_y == "양품", 0, 1)

# %%
# 데이터 분할(train,test 데이터 7:3 비율로 분할)
# train_test_split(x: 설명변수 데이터 )
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_x_dummy,df_raw_y,test_size=0.3,random_state=1234)
print("train data X size:{}".format(df_train_x.shape))
print("train data Y size:{}".format(df_train_y.shape))
print("test data X size:{}".format(df_test_x.shape))
print("test data Y size:{}".format(df_test_y.shape))
# Out:
# train data X size:(2787, 36)
# train data Y size:(2787,)
# test data X size:(1195, 36)
# test data Y size:(1195,)

# %%
tree_final = DecisionTreeClassifier()
tree_final.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
v_feature_name = df_train_x.columns
df_importance = pd.DataFrame()
df_importance["Feature"] = v_feature_name
df_importance["Importance"] = tree_final.feature_importances_

df_importance.sort_values("Importance", ascending=False, inplace = True)
df_importance.round(3)
# Out:
#                        Feature  Importance
# 29          MC_6PHOS_4FIRE_1호기       0.083
# 15        MC_4DIELEC_1FIRE_2호기       0.065
# 28  MC_6PHOS_3B_1DISPENSER_2호기       0.057
# 18                 MC_5MGO_2호기       0.047
# 33               MC_7PASTE_2호기       0.045
# 2           MC_1BLACK_2RTD_1호기       0.045
# 23  MC_6PHOS_2G_1DISPENSER_1호기       0.044
# 35               MC_8AGING_2호기       0.038
# 7              MC_2AG_2RTD_2호기       0.038
# 16        MC_4DIELEC_1FIRE_3호기       0.036
# 10        MC_3BUS_1DEVELOP_1호기       0.035
# 24  MC_6PHOS_2G_1DISPENSER_2호기       0.031
# 0         MC_1BLACK_1PRINT_1호기       0.029
# 30          MC_6PHOS_4FIRE_2호기       0.027
# 25        MC_6PHOS_2G_2DRY_1호기       0.026
# 4            MC_2AG_1PRINT_1호기       0.026
# 9         MC_2AG_3EXPOSURE_2호기       0.024
# 20  MC_6PHOS_1R_1DISPENSER_2호기       0.024
# 8         MC_2AG_3EXPOSURE_1호기       0.023
# 14        MC_4DIELEC_1FIRE_1호기       0.023
# 3           MC_1BLACK_2RTD_2호기       0.022
# 1         MC_1BLACK_1PRINT_2호기       0.022
# 22        MC_6PHOS_1R_2DRY_2호기       0.021
# 13           MC_3BUS_2FIRE_2호기       0.020
# 26        MC_6PHOS_2G_2DRY_2호기       0.020
# 31          MC_6PHOS_4FIRE_3호기       0.018
# 19  MC_6PHOS_1R_1DISPENSER_1호기       0.018
# 12           MC_3BUS_2FIRE_1호기       0.017
# 34               MC_8AGING_1호기       0.016
# 21        MC_6PHOS_1R_2DRY_1호기       0.014
# 6              MC_2AG_2RTD_1호기       0.012
# 27  MC_6PHOS_3B_1DISPENSER_1호기       0.011
# 5            MC_2AG_1PRINT_2호기       0.009
# 17                 MC_5MGO_1호기       0.008
# 32               MC_7PASTE_1호기       0.006
# 11        MC_3BUS_1DEVELOP_2호기       0.000

# %% [markdown]
# ## PROCESS

# %%
# drop: X변수와 변수 삭제
df_raw_x = MFG_PROCESS.drop(["JUDGE","PANEL_ID","LOT_ID"], axis=1, inplace=False)
df_raw_y = MFG_PROCESS["JUDGE"]
# get_dummies: 데이터의 문자형 변수에 대한 더미변수 생성
df_x_dummy = pd.get_dummies(df_raw_x)
df_raw_y = np.where(df_raw_y == "양품", 0, 1)

# %%
# 데이터 분할(train,test 데이터 7:3 비율로 분할)
# train_test_split(x: 설명변수 데이터 )
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_x_dummy,df_raw_y,test_size=0.3,random_state=1234)
print("train data X size:{}".format(df_train_x.shape))
print("train data Y size:{}".format(df_train_y.shape))
print("test data X size:{}".format(df_test_x.shape))
print("test data Y size:{}".format(df_test_y.shape))
# Out:
# train data X size:(2787, 70)
# train data Y size:(2787,)
# test data X size:(1195, 70)
# test data Y size:(1195,)

# %%
tree_final = DecisionTreeClassifier()
tree_final.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
v_feature_name = df_train_x.columns
df_importance = pd.DataFrame()
df_importance["Feature"] = v_feature_name
df_importance["Importance"] = tree_final.feature_importances_

df_importance.sort_values("Importance", ascending=False, inplace = True)
df_importance.round(3)
# Out:
#                         Feature  Importance
# 15        AG_RTD_TEMP_GLASS_OUT       0.375
# 23       BUS_DEVELOP_TEMP_TANK2       0.181
# 41    DIELEC_FIRE_EXHAUST_HEAT5       0.027
# 22       BUS_DEVELOP_TEMP_TANK1       0.027
# 51   PHOS_R_DRY_TEMP_HOOD_START       0.024
# 68      PHOS_FIRE_EXHAUST_HEAT3       0.023
# 0    BLACK_RTD_TEMP_GLASS_START       0.023
# 44  PHOS_R_DRY_TEMP_GLASS_START       0.019
# 47     PHOS_R_DRY_TEMP_WALL_MAX       0.019
# 38    DIELEC_FIRE_EXHAUST_HEAT2       0.018
# 24       BUS_DEVELOP_TEMP_TANK3       0.018
# 32     BUS_FIRE_TEMP_ANEAL_CH03       0.016
# 61     PHOS_G_DRY_TEMP_HOOD_MAX       0.012
# 67      PHOS_FIRE_EXHAUST_HEAT2       0.011
# 66      PHOS_FIRE_EXHAUST_HEAT1       0.010
# 2     BLACK_RTD_TEMP_WALL_START       0.010
# 52     PHOS_R_DRY_TEMP_HOOD_MAX       0.009
# 26            BUS_DEVELOP_PRES3       0.008
# 43    DIELEC_FIRE_EXHAUST_HEAT7       0.008
# 5            BLACK_RTD_PRES_END       0.008
# 3       BLACK_RTD_TEMP_WALL_MAX       0.008
# 49          PHOS_R_DRY_PRES_END       0.008
# 8       BLACK_RTD_TEMP_HOOD_MAX       0.008
# 58          PHOS_G_DRY_PRES_END       0.007
# 45    PHOS_R_DRY_TEMP_GLASS_END       0.007
# 27      BUS_FIRE_TEMP_KEEP_CH01       0.007
# 31     BUS_FIRE_TEMP_ANEAL_CH02       0.007
# 12         AG_RTD_TEMP_WALL_MAX       0.007
# 57        PHOS_G_DRY_PRES_START       0.007
# 35  DIELEC_FIRE_TEMP_ANEAL_CH02       0.006
# 28      BUS_FIRE_TEMP_KEEP_CH02       0.006
# 21       BUS_DEVELOP_TEMP_OVEN3       0.006
# 34  DIELEC_FIRE_TEMP_ANEAL_CH01       0.005
# 14              AG_RTD_PRES_END       0.005
# 18        AG_EXPOSURE_TEMP_MASK       0.005
# 39    DIELEC_FIRE_EXHAUST_HEAT3       0.005
# 69      PHOS_FIRE_EXHAUST_HEAT4       0.005
# 65    PHOS_FIRE_TEMP_ANEAL_CH04       0.004
# 37    DIELEC_FIRE_EXHAUST_HEAT1       0.004
# 46   PHOS_R_DRY_TEMP_WALL_START       0.004
# 50    PHOS_R_DRY_TEMP_GLASS_OUT       0.004
# 59    PHOS_G_DRY_TEMP_GLASS_OUT       0.004
# 60   PHOS_G_DRY_TEMP_HOOD_START       0.004
# 16       AG_RTD_TEMP_HOOD_START       0.004
# 4          BLACK_RTD_PRES_START       0.003
# 19       BUS_DEVELOP_TEMP_OVEN1       0.003
# 29      BUS_FIRE_TEMP_KEEP_CH03       0.003
# 1      BLACK_RTD_TEMP_GLASS_END       0.002
# 54    PHOS_G_DRY_TEMP_GLASS_END       0.002
# 25            BUS_DEVELOP_PRES2       0.002
# 7     BLACK_RTD_TEMP_HOOD_START       0.001
# 36  DIELEC_FIRE_TEMP_ANEAL_CH03       0.000
# 42    DIELEC_FIRE_EXHAUST_HEAT6       0.000
# 11       AG_RTD_TEMP_WALL_START       0.000
# 6      BLACK_RTD_TEMP_GLASS_OUT       0.000
# 9       AG_RTD_TEMP_GLASS_START       0.000
# 33   DIELEC_FIRE_TEMP_KEEP_CH01       0.000
# 64    PHOS_FIRE_TEMP_ANEAL_CH03       0.000
# 63    PHOS_FIRE_TEMP_ANEAL_CH02       0.000
# 62    PHOS_FIRE_TEMP_ANEAL_CH01       0.000
# 40    DIELEC_FIRE_EXHAUST_HEAT4       0.000
# 55   PHOS_G_DRY_TEMP_WALL_START       0.000
# 10        AG_RTD_TEMP_GLASS_END       0.000
# 56     PHOS_G_DRY_TEMP_WALL_MAX       0.000
# 53  PHOS_G_DRY_TEMP_GLASS_START       0.000
# 13            AG_RTD_PRES_START       0.000
# 48        PHOS_R_DRY_PRES_START       0.000
# 17         AG_RTD_TEMP_HOOD_MAX       0.000
# 20       BUS_DEVELOP_TEMP_OVEN2       0.000
# 30     BUS_FIRE_TEMP_ANEAL_CH01       0.000

# %% [markdown]
# # TAT

# %%
# drop: X변수와 변수 삭제
df_raw_x = MFG_TAT.drop(["JUDGE","PANEL_ID","LOT_ID"], axis=1, inplace=False)
df_raw_y = MFG_TAT["JUDGE"]
# get_dummies: 데이터의 문자형 변수에 대한 더미변수 생성
df_x_dummy = pd.get_dummies(df_raw_x)
df_raw_y = np.where(df_raw_y == "양품", 0, 1)

# %%
# 데이터 분할(train,test 데이터 7:3 비율로 분할)
# train_test_split(x: 설명변수 데이터 )
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_x_dummy,df_raw_y,test_size=0.3,random_state=1234)
print("train data X size:{}".format(df_train_x.shape))
print("train data Y size:{}".format(df_train_y.shape))
print("test data X size:{}".format(df_test_x.shape))
print("test data Y size:{}".format(df_test_y.shape))
# Out:
# train data X size:(2787, 16)
# train data Y size:(2787,)
# test data X size:(1195, 16)
# test data Y size:(1195,)

# %%
tree_final = DecisionTreeClassifier()
tree_final.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
v_feature_name = df_train_x.columns
df_importance = pd.DataFrame()
df_importance["Feature"] = v_feature_name
df_importance["Importance"] = tree_final.feature_importances_

df_importance.sort_values("Importance", ascending=False, inplace = True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 7          TAT_4DIELEC_FIRE       0.224
# 6            TAT_3BUS_2FIRE       0.150
# 15               TAT_8AGING       0.092
# 2            TAT_2AG_1PRINT       0.068
# 14          TAT_6PHOS_4FIRE       0.057
# 4         TAT_2AG_3EXPOSURE       0.057
# 10        TAT_6PHOS_1R_2DRY       0.050
# 13  TAT_6PHOS_3B_1DISPENSER       0.044
# 5         TAT_3BUS_1DEVELOP       0.044
# 3              TAT_2AG_2RTD       0.041
# 11  TAT_6PHOS_2G_1DISPENSER       0.037
# 9   TAT_6PHOS_1R_1DISPENSER       0.034
# 12        TAT_6PHOS_2G_2DRY       0.032
# 0         TAT_1BLACK_1PRINT       0.031
# 1           TAT_1BLACK_2RTD       0.025
# 8                  TAT_5MGO       0.014
