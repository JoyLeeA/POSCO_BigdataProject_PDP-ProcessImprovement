# %%
import pandas_profiling

# %%
import pandas as pd
import numpy as np

# %%
df_machine = pd.read_csv('/home/pirl/빅데이터 프로젝트/raw data/MFG_MACHINE.csv', engine='python', encoding='EUC-KR')
df_machine
# Out:
#      JUDGE   LOT_ID PANEL_ID DATE_1BLACK       TIME_1BLACK         TIME_2AG  \
# 0       양품  LOT-101   PNL-01  2019-04-01   2019-04-01 0:01  2019-04-01 5:21
# 1       양품  LOT-101   PNL-02  2019-04-01   2019-04-01 0:45  2019-04-01 6:05
# 2       양품  LOT-101   PNL-03  2019-04-01   2019-04-01 1:29  2019-04-01 6:49
# 3       양품  LOT-101   PNL-04  2019-04-01   2019-04-01 2:13  2019-04-01 7:33
# 4       양품  LOT-101   PNL-05  2019-04-01   2019-04-01 2:58  2019-04-01 8:18
# ...    ...      ...      ...         ...               ...              ...
# 3995    명점  LOT-300   PNL-16  2019-08-01  2019-08-01 21:38  2019-08-02 2:58
# 3996    양품  LOT-300   PNL-17  2019-08-01  2019-08-01 22:23  2019-08-02 3:43
# 3997    양품  LOT-300   PNL-18  2019-08-01  2019-08-01 23:07  2019-08-02 4:27
# 3998    명점  LOT-300   PNL-19  2019-08-01  2019-08-01 23:51  2019-08-02 5:11
# 3999    양품  LOT-300   PNL-20  2019-08-02   2019-08-02 0:35  2019-08-02 5:55
#
# ...

# %%
df_tat = pd.read_csv('/home/pirl/빅데이터 프로젝트/raw data/MFG_TAT.csv', engine='python', encoding='EUC-KR')
df_tat
# Out:
#      JUDGE   LOT_ID PANEL_ID       TIME_1BLACK         TIME_2AG  \
# 0       양품  LOT-101   PNL-01   2019-04-01 0:01  2019-04-01 5:21
# 1       양품  LOT-101   PNL-02   2019-04-01 0:45  2019-04-01 6:05
# 2       양품  LOT-101   PNL-03   2019-04-01 1:29  2019-04-01 6:49
# 3       양품  LOT-101   PNL-04   2019-04-01 2:13  2019-04-01 7:33
# 4       양품  LOT-101   PNL-05   2019-04-01 2:58  2019-04-01 8:18
# ...    ...      ...      ...               ...              ...
# 3995    명점  LOT-300   PNL-16  2019-08-01 21:38  2019-08-02 2:58
# 3996    양품  LOT-300   PNL-17  2019-08-01 22:23  2019-08-02 3:43
# 3997    양품  LOT-300   PNL-18  2019-08-01 23:07  2019-08-02 4:27
# 3998    명점  LOT-300   PNL-19  2019-08-01 23:51  2019-08-02 5:11
# 3999    양품  LOT-300   PNL-20   2019-08-02 0:35  2019-08-02 5:55
#
#              TIME_3BUS      TIME_4DIELEC        TIME_5MGO        TIME_6PHOS  \
# 0     2019-04-01 11:01  2019-04-06 13:41  2019-04-11 3:41  2019-04-03 20:20
# ...

# %%
result_machine_tat = pd.merge(df_machine, df_tat, on=['JUDGE','LOT_ID','PANEL_ID','TIME_1BLACK','TIME_2AG','TIME_3BUS','TIME_4DIELEC','TIME_5MGO','TIME_6PHOS','TIME_7PASTE','TIME_8AGING']) # 교집합 값 inner
result_machine_tat
# Out:
#      JUDGE   LOT_ID PANEL_ID DATE_1BLACK       TIME_1BLACK         TIME_2AG  \
# 0       양품  LOT-101   PNL-01  2019-04-01   2019-04-01 0:01  2019-04-01 5:21
# 1       양품  LOT-101   PNL-02  2019-04-01   2019-04-01 0:45  2019-04-01 6:05
# 2       양품  LOT-101   PNL-03  2019-04-01   2019-04-01 1:29  2019-04-01 6:49
# 3       양품  LOT-101   PNL-04  2019-04-01   2019-04-01 2:13  2019-04-01 7:33
# 4       양품  LOT-101   PNL-05  2019-04-01   2019-04-01 2:58  2019-04-01 8:18
# ...    ...      ...      ...         ...               ...              ...
# 3995    명점  LOT-300   PNL-16  2019-08-01  2019-08-01 21:38  2019-08-02 2:58
# 3996    양품  LOT-300   PNL-17  2019-08-01  2019-08-01 22:23  2019-08-02 3:43
# 3997    양품  LOT-300   PNL-18  2019-08-01  2019-08-01 23:07  2019-08-02 4:27
# 3998    명점  LOT-300   PNL-19  2019-08-01  2019-08-01 23:51  2019-08-02 5:11
# 3999    양품  LOT-300   PNL-20  2019-08-02   2019-08-02 0:35  2019-08-02 5:55
#
# ...

# %%
df_process = pd.read_csv('/home/pirl/빅데이터 프로젝트/raw data/MFG_PROCESS.csv', engine='python', encoding='EUC-KR')
df_process
# Out:
#      JUDGE   LOT_ID PANEL_ID       TIME_1BLACK          TIME_2AG  \
# 0       양품  LOT-101   PNL-01  2019-04-01T00:01  2019-04-01T05:21
# 1       양품  LOT-101   PNL-02  2019-04-01T00:45  2019-04-01T06:05
# 2       양품  LOT-101   PNL-03  2019-04-01T01:29  2019-04-01T06:49
# 3       양품  LOT-101   PNL-04  2019-04-01T02:13  2019-04-01T07:33
# 4       양품  LOT-101   PNL-05  2019-04-01T02:58  2019-04-01T08:18
# ...    ...      ...      ...               ...               ...
# 3995    명점  LOT-300   PNL-16  2019-08-01T21:38  2019-08-02T02:58
# 3996    양품  LOT-300   PNL-17  2019-08-01T22:23  2019-08-02T03:43
# 3997    양품  LOT-300   PNL-18  2019-08-01T23:07  2019-08-02T04:27
# 3998    명점  LOT-300   PNL-19  2019-08-01T23:51  2019-08-02T05:11
# 3999    양품  LOT-300   PNL-20  2019-08-02T00:35  2019-08-02T05:55
#
#              TIME_3BUS      TIME_4DIELEC         TIME_5MGO        TIME_6PHOS  \
# 0     2019-04-01T11:01  2019-04-06T13:41  2019-04-11T03:41  2019-04-03T20:20
# ...

# %%
# result_all = pd.merge(result_machine_tat, df_process, on=['JUDGE','LOT_ID','PANEL_ID','TIME_1BLACK','TIME_2AG','TIME_3BUS','TIME_4DIELEC','TIME_5MGO','TIME_6PHOS','TIME_7PASTE','TIME_8AGING']) # 교집합 값 inner
result_all = pd.merge(result_machine_tat, df_process, on=['JUDGE','LOT_ID','PANEL_ID','TIME_1BLACK']) # 교집합 값 inner
result_all
# Out:
# Empty DataFrame
# ...

# %%
result_all = pd.merge(result_machine_tat, df_process, on=['JUDGE','LOT_ID','PANEL_ID','TIME_1BLACK','TIME_2AG','TIME_3BUS','TIME_4DIELEC','TIME_5MGO','TIME_6PHOS','TIME_7PASTE','TIME_8AGING']) # 교집합 값 inner
# result_machine_process = pd.merge(df_machine, df_process, on=['LOT_ID']) # 교집합 값 inner
result_machine_process
# Out:
#       JUDGE_x   LOT_ID PANEL_ID_x DATE_1BLACK    TIME_1BLACK_x  \
# 0          양품  LOT-101     PNL-01  2019-04-01  2019-04-01 0:01
# 1          양품  LOT-101     PNL-01  2019-04-01  2019-04-01 0:01
# 2          양품  LOT-101     PNL-01  2019-04-01  2019-04-01 0:01
# 3          양품  LOT-101     PNL-01  2019-04-01  2019-04-01 0:01
# 4          양품  LOT-101     PNL-01  2019-04-01  2019-04-01 0:01
# ...       ...      ...        ...         ...              ...
# 79995      양품  LOT-300     PNL-20  2019-08-02  2019-08-02 0:35
# 79996      양품  LOT-300     PNL-20  2019-08-02  2019-08-02 0:35
# 79997      양품  LOT-300     PNL-20  2019-08-02  2019-08-02 0:35
# 79998      양품  LOT-300     PNL-20  2019-08-02  2019-08-02 0:35
# 79999      양품  LOT-300     PNL-20  2019-08-02  2019-08-02 0:35
#
#             TIME_2AG_x       TIME_3BUS_x    TIME_4DIELEC_x      TIME_5MGO_x  \
# 0      2019-04-01 5:21  2019-04-01 11:01  2019-04-06 13:41  2019-04-11 3:41
# ...

# %%
pr = result_machine_tat.profile_report()
pr.to_file('./pr_report_machine_tat.html')
